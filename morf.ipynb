# %% [markdown]
# # Morphologies

# %%
import pandas as pd

# %% [markdown]
# # CRW

# %%
df_crw_m1 = pd.read_csv("evals/EE_sac_M1_seed42_2026-04-10_14-57-34/sac_ep.csv")
df_crw_m2 = pd.read_csv("evals/EE_sac_M2_seed42_2026-04-10_14-57-14/sac_ep.csv")
df_crw_m3 = pd.read_csv("evals/EE_sac_M3_seed42_2026-04-10_15-34-34/sac_ep.csv")

# %%
stats_m1 = df_crw_m1[["reward", "r_dist", "p_disturbance"]].agg(["mean", "std"]).round(3)
print(stats_m1)
# Out:
#       reward  r_dist  p_disturbance
# mean   0.867  -0.504          0.315
# std    0.007   0.024          0.019

# %%
stats_m2 = df_crw_m2[["reward", "r_dist", "p_disturbance"]].agg(["mean", "std"]).round(3)
print(stats_m2)
# Out:
#       reward  r_dist  p_disturbance
# mean   0.914  -0.476          0.162
# std    0.007   0.012          0.008

# %%
stats_m3 = df_crw_m3[["reward", "r_dist", "p_disturbance"]].agg(["mean", "std"]).round(3)
print(stats_m3)
# Out:
#       reward  r_dist  p_disturbance
# mean   0.926  -0.423          0.106
# std    0.012   0.025          0.018

# %% [markdown]
# ## EE

# %%
df_ee_m1 = pd.read_csv("evals/EE_sac_M1_seed42_2026-04-10_14-57-34/sac_ep.csv")
df_ee_m2 = pd.read_csv("evals/EE_sac_M2_seed42_2026-04-10_14-57-14/sac_ep.csv")
df_ee_m3 = pd.read_csv("evals/EE_sac_M3_seed42_2026-04-10_15-34-34/sac_ep.csv")

# %%
stats_m1 = df_crw_m1[["reward", "r_dist", "p_disturbance"]].agg(["mean", "std"]).round(3)
print(stats_m1)
# Out:
#       reward  r_dist  p_disturbance
# mean   0.867  -0.504          0.315
# std    0.007   0.024          0.019

# %%
stats_m2 = df_crw_m2[["reward", "r_dist", "p_disturbance"]].agg(["mean", "std"]).round(3)
print(stats_m2)
# Out:
#       reward  r_dist  p_disturbance
# mean   0.914  -0.476          0.162
# std    0.007   0.012          0.008

# %%
stats_m3 = df_crw_m3[["reward", "r_dist", "p_disturbance"]].agg(["mean", "std"]).round(3)
print(stats_m3)
# Out:
#       reward  r_dist  p_disturbance
# mean   0.926  -0.423          0.106
# std    0.012   0.025          0.018

# %% [markdown]
# # POI

# %%
df_poi_m1 = pd.read_csv("evals/POI_sac_M1_seed42_2026-04-10_18-51-37/sac_ep.csv")
df_poi_m2 = pd.read_csv("evals/POI_sac_M2_seed99_2026-04-10_21-56-02/sac_ep.csv")
df_poi_m3 = pd.read_csv("evals/POI_sac_M3_seed99_2026-04-10_22-02-43/sac_ep.csv")

# %%
stats_m1 = df_poi_m1[["reward", "r_dist", "p_disturbance"]].agg(["mean", "std"]).round(3)
print(stats_m1)
# Out:
#       reward  r_dist  p_disturbance
# mean   0.878  -0.515          0.302
# std    0.014   0.023          0.018

# %%
stats_m2 = df_poi_m2[["reward", "r_dist", "p_disturbance"]].agg(["mean", "std"]).round(3)
print(stats_m2)
# Out:
#       reward  r_dist  p_disturbance
# mean   0.918  -0.450          0.180
# std    0.010   0.031          0.026

# %%
stats_m3 = df_poi_m3[["reward", "r_dist", "p_disturbance"]].agg(["mean", "std"]).round(3)
print(stats_m3)
# Out:
#       reward  r_dist  p_disturbance
# mean   0.935  -0.379          0.132
# std    0.017   0.021          0.012

# %% [markdown]
# # LPOI

# %%
df_lpoi_m1 = pd.read_csv("evals/LPOI_sac_M1_seed42_2026-04-10_19-37-24/sac_ep.csv")
df_lpoi_m2 = pd.read_csv("evals/LPOI_sac_M2_seed99_2026-04-10_22-08-57/sac_ep.csv")
df_lpoi_m3 = pd.read_csv("evals/LPOI_sac_M3_seed42_2026-04-10_20-21-10/sac_ep.csv")

# %%
stats_m1 = df_lpoi_m1[["reward", "r_dist", "p_disturbance"]].agg(["mean", "std"]).round(3)
print(stats_m1)
# Out:
#       reward  r_dist  p_disturbance
# mean   0.893  -0.516          0.299
# std    0.009   0.013          0.011

# %%
stats_m2 = df_lpoi_m2[["reward", "r_dist", "p_disturbance"]].agg(["mean", "std"]).round(3)
print(stats_m2)
# Out:
#       reward  r_dist  p_disturbance
# mean   0.920  -0.436          0.188
# std    0.011   0.017          0.016

# %%
stats_m3 = df_lpoi_m3[["reward", "r_dist", "p_disturbance"]].agg(["mean", "std"]).round(3)
print(stats_m3)
# Out:
#       reward  r_dist  p_disturbance
# mean   0.923  -0.425          0.108
# std    0.008   0.019          0.011
